# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_excel(r'C:\Users\sathish\Music\rainfall in india 1901-2015 (Updated).xlsx')

# %%
df.head(2)
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR  APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2  2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2  0.0  446.1  537.1
#
#      JUL    AUG  ...    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# 0  365.1  481.1  ...  558.2   33.6  3373.2    136.3    560.3   1696.3
# 1  228.9  753.7  ...  359.0  160.5  3520.7    159.8    458.3   2185.9
#
#    Oct-Dec  Unnamed: 19  Unnamed: 20  Unnamed: 21
# 0    980.3          NaN          NaN          NaN
# 1    716.7          NaN          NaN          NaN
#
# [2 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4116 non-null   float64
#  3   FEB          4116 non-null   float64
#  4   MAR          4116 non-null   float64
#  5   APR          4116 non-null   float64
#  6   MAY          4116 non-null   float64
#  7   JUN          4116 non-null   float64
#  8   JUL          4116 non-null   float64
#  9   AUG          4116 non-null   float64
#  10  SEP          4116 non-null   float64
#  11  OCT          4116 non-null   float64
#  12  NOV          4116 non-null   float64
#  13  DEC          4116 non-null   float64
#  14  ANNUAL       4116 non-null   float64
#  15  Jan-Feb      4116 non-null   float64
#  16  Mar-May      4116 non-null   float64
#  17  Jun-Sep      4116 non-null   float64
# ...

# %%
df.groupby(['SUBDIVISION'],as_index=False)['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC'].mean()
# Out:
# C:\Users\sathish\AppData\Local\Temp\ipykernel_15004\1668376466.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['SUBDIVISION'],as_index=False)['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC'].mean()
#                            SUBDIVISION         JAN         FEB         MAR  \
# 0            ANDAMAN & NICOBAR ISLANDS   52.637273   27.994545   31.824074
# 1                    ARUNACHAL PRADESH   46.810309   90.177320  153.527368
# 2                    ASSAM & MEGHALAYA   16.974783   31.441739   79.026957
# 3                                BIHAR   13.386087   14.393913   10.124348
# 4                         CHHATTISGARH   14.206957   19.259130   15.266957
# 5               COASTAL ANDHRA PRADESH    7.483478   12.923478   13.221739
# 6                    COASTAL KARNATAKA    1.937719    1.518261    6.357391
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4111    False
# 4112    False
# 4113    False
# 4114    False
# 4115    False
# Length: 4116, dtype: bool

# %%
for x in df[df.duplicated()]:
    print(x)
# Out:
# SUBDIVISION
# YEAR
# JAN
# FEB
# MAR
# APR
# MAY
# JUN
# JUL
# AUG
# SEP
# OCT
# NOV
# DEC
# ANNUAL
# Jan-Feb
# Mar-May
# Jun-Sep
# Oct-Dec
# Unnamed: 19
# Unnamed: 20
# Unnamed: 21

# %%
df.drop(['Unnamed: 19','Unnamed: 20','Unnamed: 21'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.drop(['Unnamed: 19','Unnamed: 20','Unnamed: 21'],axis=1,inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
# ...

# %%
df.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb', 'Mar-May',
#        'Jun-Sep', 'Oct-Dec', '1st Phase', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
df.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].sum().sort_values(by='ANNUAL',ascending=False)
# Out:
#                            SUBDIVISION         ANNUAL
# 6                    COASTAL KARNATAKA  391680.437719
# 17                        KONKAN & GOA  342432.900000
# 16                              KERALA  336432.400000
# 1                    ARUNACHAL PRADESH  332592.990834
# 0            ANDAMAN & NICOBAR ISLANDS  322304.691894
# 28  SUB HIMALAYAN WEST BENGAL & SIKKIM  316503.400000
# 2                    ASSAM & MEGHALAYA  296780.300000
# 21              NAGA MANI MIZO TRIPURA  279868.400000
# 18                         LAKSHADWEEP  182381.451892
# 10                GANGETIC WEST BENGAL  171406.800000
# 31                         UTTARAKHAND  168554.700000
# 23                              ORISSA  167689.700000
# 4                         CHHATTISGARH  157749.200000
# 15                           JHARKHAND  150570.000000
# 13                    HIMACHAL PRADESH  144939.100000
# 7                  EAST MADHYA PRADESH  138575.400000
# ...

# %%
df.groupby(['SUBDIVISION'],as_index=False)['Jun-Sep'].mean().sort_values(by='Jun-Sep',ascending=False)
# Out:
#                            SUBDIVISION      Jun-Sep
# 6                    COASTAL KARNATAKA  2981.625217
# 17                        KONKAN & GOA  2794.136522
# 1                    ARUNACHAL PRADESH  2270.764379
# 28  SUB HIMALAYAN WEST BENGAL & SIKKIM  2126.389565
# 16                              KERALA  2022.852174
# 2                    ASSAM & MEGHALAYA  1720.592174
# 0            ANDAMAN & NICOBAR ISLANDS  1711.152613
# 21              NAGA MANI MIZO TRIPURA  1609.950435
# 4                         CHHATTISGARH  1204.496522
# 23                              ORISSA  1158.820000
# 31                         UTTARAKHAND  1131.369565
# 10                GANGETIC WEST BENGAL  1130.666957
# 15                           JHARKHAND  1084.510435
# 7                  EAST MADHYA PRADESH  1076.013043
# 3                                BIHAR  1015.785217
# 18                         LAKSHADWEEP   980.720528
# 32                            VIDARBHA   964.406087
# ...

# %%
def category(year):
    if year>1900 and year<=1925:
        return 'Quarter1'
    if year>1925 and year<=1950:
        return 'Quarter2'
    if year>1950 and year<=1975:
        return 'Quarter3'
    if year>1975 and year<=2000:
        return 'Quarter4'
    else:
        return 'Phase5'

# %%
df['Phase']=df['YEAR'].apply(category)

# %%
df
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
df.to_csv(r'C:\Users\sathish\Music\rain fall in india.csv',index=False)

# %%
df_p5.tail(3)
# Out:
#       SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN    JUL    AUG  \
# 4113  LAKSHADWEEP  2013  26.2  34.4  37.5   5.3   88.3  426.2  296.4  154.4
# 4114  LAKSHADWEEP  2014  53.2  16.1   4.4  14.9   57.4  244.1  116.1  466.1
# 4115  LAKSHADWEEP  2015   2.2   0.5   3.7  87.1  133.1  296.6  257.5  146.4
#
#         SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec  \
# 4113  180.0   72.8   78.1   26.7  1426.3     60.6    131.1   1057.0    177.6
# 4114  132.2  169.2   59.0   62.3  1395.0     69.3     76.7    958.5    290.5
# 4115  160.4  165.4  231.0  159.0  1642.9      2.7    223.9    860.9    555.4
#
#        Phase
# 4113  Phase5
# 4114  Phase5
# 4115  Phase5

# %%
#### Quarter 1 max and median and low rainfall across all states
q1_max=df_q1.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='ANNUAL',ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #### Quarter 1 max and median and low rainfall across all states
# ----> 2 q1_max=df_q1.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='ANNUAL',ascending=False).head(10)
#
# NameError: name 'df_q1' is not defined

# %%
sns.barplot(x='SUBDIVISION',y='ANNUAL',data=q1_max)
sns.set(rc={'figure.figsize':(25,6)})
plt.show()

# %%
q1_max
# Out:
#                            SUBDIVISION  ANNUAL
# 1                    ARUNACHAL PRADESH  5691.4
# 16                              KERALA  4226.3
# 6                    COASTAL KARNATAKA  3872.8
# 0            ANDAMAN & NICOBAR ISLANDS  3576.4
# 28  SUB HIMALAYAN WEST BENGAL & SIKKIM  3513.3
# 17                        KONKAN & GOA  3464.6
# 2                    ASSAM & MEGHALAYA  3165.2
# 21              NAGA MANI MIZO TRIPURA  3013.2
# 18                         LAKSHADWEEP  2158.8
# 31                         UTTARAKHAND  2103.0

# %%
##  In Quarter1 (1900-1925)  maximum Annual rainfall occurs in below states
Arunachal Pradesh,Kerala,Coastal Karnataka, nicobar islands,lakshadweep , assam and meghalaya , goa, tripura, uttarkhand
ARUNACHAL PRADESH
KERALA
COASTAL KARNATAKA
ANDAMAN & NICOBAR ISLANDS
SUB HIMALAYAN WEST BENGAL & SIKKIM
KONKAN & GOA
ASSAM & MEGHALAYA
NAGA MANI MIZO TRIPURA
LAKSHADWEEP
UTTARAKHAND

# %%
### Median Rainfall states in 1st Quarter
q1_mean=df_q1.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='ANNUAL',ascending=False).head(10)

# %%
sns.barplot(x='SUBDIVISION',y='ANNUAL',data=q1_mean)
plt.show()

# %%
##### Average RainFall in 1st Quarter in india ( Top 10 states)
ARUNACHAL PRADESH
COASTAL KARNATAKA
KERALA
ANDAMAN & NICOBAR ISLANDS
SUB HIMALAYAN WEST BENGAL & SIKKIM
ASSAM & MEGHALAYA
KONKAN & GOA
NAGA MANI MIZO TRIPURA
LAKSHADWEEP
UTTARAKHAND

# %%
q1_low=df_q1.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='ANNUAL',ascending=True).head(15)

# %%
q1_low
# Out:
#                    SUBDIVISION  ANNUAL
# 34              WEST RAJASTHAN    62.2
# 26          SAURASHTRA & KUTCH   117.7
# 12  HARYANA DELHI & CHANDIGARH   234.6
# 8               EAST RAJASTHAN   273.6
# 24                      PUNJAB   339.6
# 20                  MATATHWADA   361.0
# 35          WEST UTTAR PRADESH   371.9
# 11              GUJARAT REGION   392.7
# 25                  RAYALSEEMA   433.4
# 30                   TELANGANA   436.8

# %%
#### Minimum rainfall states in india during 1st Quarter are is as follows.
west rajasthan,Saurashtra,Delhi(haryana),Rajasthan,Punjab,Uttarpradesh,Gujarat,Rayalaseema,Telangana

# %%
sns.barplot(x='SUBDIVISION',y='ANNUAL',data=q1_low)
plt.show()

# %%
##### 2nd Quarter max,average,min rainfall in india 
q1_low=df_q1.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='ANNUAL',ascending=True)
q2_low=df_q1.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='ANNUAL',ascending=True)
q2_mean=df_q2.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='ANNUAL',ascending=False)
q2_max=df_q2.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='ANNUAL',ascending=False)

# %%
sns.barplot(x='SUBDIVISION',y='ANNUAL',data=q1_max)
sns.set(rc={'figure.figsize':(25,6)})
plt.show()

# %%
 ####### During 2nd Quarter maximum Rainfall in below 10 states are is as follows.
ARUNACHAL PRADESH
KERALA
COASTAL KARNATAKA
ANDAMAN & NICOBAR ISLANDS
SUB HIMALAYAN WEST BENGAL & SIKKIM
KONKAN & GOA
ASSAM & MEGHALAYA
NAGA MANI MIZO TRIPURA
LAKSHADWEEP
UTTARAKHAND
##### 
Note : During 1st and 2nd quarter above states are having maximum rainfall

# %%
q2_mean
# Out:
#                            SUBDIVISION       ANNUAL
# 1                    ARUNACHAL PRADESH  4393.488963
# 6                    COASTAL KARNATAKA  3337.748000
# 17                        KONKAN & GOA  3057.300000
# 0            ANDAMAN & NICOBAR ISLANDS  3022.715379
# 16                              KERALA  3011.116000
# 21              NAGA MANI MIZO TRIPURA  2746.648000
# 28  SUB HIMALAYAN WEST BENGAL & SIKKIM  2715.044000
# 2                    ASSAM & MEGHALAYA  2680.968000
# 18                         LAKSHADWEEP  1578.539707
# 23                              ORISSA  1522.452000

# %%
##### Average RainFall in 2nd Quarter in india ( Top 10 states)
ARUNACHAL PRADESH
COASTAL KARNATAKA
KERALA
ANDAMAN & NICOBAR ISLANDS
SUB HIMALAYAN WEST BENGAL & SIKKIM
ASSAM & MEGHALAYA
KONKAN & GOA
NAGA MANI MIZO TRIPURA
LAKSHADWEEP
ORISSA  
## Note: Top states which are listed above are standing in 1st and 2nd quarters as well only Orissa comes in 2nd Quarter but 
Uttarakhand comes in 1st Quarter

# %%
q2_low
# Out:
#                    SUBDIVISION  ANNUAL
# 34              WEST RAJASTHAN   137.4
# 26          SAURASHTRA & KUTCH   179.4
# 12  HARYANA DELHI & CHANDIGARH   278.9
# 8               EAST RAJASTHAN   400.7
# 24                      PUNJAB   403.8
# 11              GUJARAT REGION   473.8
# 25                  RAYALSEEMA   510.9
# 35          WEST UTTAR PRADESH   516.3
# 22    NORTH INTERIOR KARNATAKA   535.7
# 20                  MATATHWADA   540.9

# %%
q1_lo
# Out:
#                    SUBDIVISION  ANNUAL
# 34              WEST RAJASTHAN    62.2
# 26          SAURASHTRA & KUTCH   117.7
# 12  HARYANA DELHI & CHANDIGARH   234.6
# 8               EAST RAJASTHAN   273.6
# 24                      PUNJAB   339.6
# 20                  MATATHWADA   361.0
# 35          WEST UTTAR PRADESH   371.9
# 11              GUJARAT REGION   392.7
# 25                  RAYALSEEMA   433.4
# 30                   TELANGANA   436.8

# %%
### 2nd Quarter low rainfall States                              
WEST RAJASTHAN	137.4
SAURASHTRA & KUTCH	179.4
HARYANA DELHI & CHANDIGARH	278.9
EAST RAJASTHAN	400.7
PUNJAB	403.8
GUJARAT REGION	473.8
RAYALSEEMA	510.9
WEST UTTAR PRADESH	516.3
NORTH INTERIOR KARNATAKA	535.7                                             
MATATHWADA	540.9
#### 1st Quarter low rainfall States
WEST RAJASTHAN	62.2
SAURASHTRA & KUTCH	117.7
HARYANA DELHI & CHANDIGARH	234.6
EAST RAJASTHAN	273.6
PUNJAB	339.6
MATATHWADA	361.0
WEST UTTAR PRADESH	371.9
GUJARAT REGION	392.7
RAYALSEEMA	433.4
TELANGANA	436.8

### Note : The above listed Top 8 States are having low rainfall rate in 1st Quarter and 2nd Quarter as well
except North Karnataka.

# %%
##### 2nd Quarter max,average,min rainfall in india 
q3_low=df_q3.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='ANNUAL',ascending=True).head(15)
q3_mean=df_q3.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='ANNUAL',ascending=False).head(10)
q3_max=df_q3.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='ANNUAL',ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 ##### 2nd Quarter max,average,min rainfall in india
# ----> 2 q3_low=df_q3.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='ANNUAL',ascending=True).head(15)
#       3 q3_mean=df_q3.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='ANNUAL',ascending=False).head(10)
#       4 q3_max=df_q3.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='ANNUAL',ascending=False).head(10)
#
# NameError: name 'df_q3' is not defined

# %%
##### 2nd Quarter max,average,min rainfall in india 
q4_low=df_q4.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='ANNUAL',ascending=True).head(15)
q4_mean=df_q4.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='ANNUAL',ascending=False).head(10)
q4_max=df_q4.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='ANNUAL',ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 ##### 2nd Quarter max,average,min rainfall in india
# ----> 2 q4_low=df_q4.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='ANNUAL',ascending=True).head(15)
#       3 q4_mean=df_q4.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='ANNUAL',ascending=False).head(10)
#       4 q4_max=df_q4.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='ANNUAL',ascending=False).head(10)
#
# NameError: name 'df_q4' is not defined

# %%
##### 2nd Quarter max,average,min rainfall in india 
p5_low=df_p5.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='ANNUAL',ascending=True).head(15)
p5_mean=df_p5.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='ANNUAL',ascending=False).head(10)
p5_max=df_p5.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='ANNUAL',ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 ##### 2nd Quarter max,average,min rainfall in india
# ----> 2 p5_low=df_p5.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='ANNUAL',ascending=True).head(15)
#       3 p5_mean=df_p5.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='ANNUAL',ascending=False).head(10)
#       4 p5_max=df_p5.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='ANNUAL',ascending=False).head(10)
#
# NameError: name 'df_p5' is not defined

# %%
q4_max
# Out:
#                            SUBDIVISION  ANNUAL
# 6                    COASTAL KARNATAKA  4636.3
# 1                    ARUNACHAL PRADESH  4155.4
# 17                        KONKAN & GOA  3814.5
# 28  SUB HIMALAYAN WEST BENGAL & SIKKIM  3655.2
# 0            ANDAMAN & NICOBAR ISLANDS  3625.3
# 16                              KERALA  3410.8
# 2                    ASSAM & MEGHALAYA  3261.7
# 21              NAGA MANI MIZO TRIPURA  2881.7
# 31                         UTTARAKHAND  2031.4
# 18                         LAKSHADWEEP  2030.9

# %%
q1_low
# Out:
#                    SUBDIVISION  ANNUAL
# 34              WEST RAJASTHAN    62.2
# 26          SAURASHTRA & KUTCH   117.7
# 12  HARYANA DELHI & CHANDIGARH   234.6
# 8               EAST RAJASTHAN   273.6
# 24                      PUNJAB   339.6
# 20                  MATATHWADA   361.0
# 35          WEST UTTAR PRADESH   371.9
# 11              GUJARAT REGION   392.7
# 25                  RAYALSEEMA   433.4
# 30                   TELANGANA   436.8

# %%
q4_low
# Out:
#                    SUBDIVISION      ANNUAL
# 26          SAURASHTRA & KUTCH   92.500000
# 34              WEST RAJASTHAN  143.000000
# 12  HARYANA DELHI & CHANDIGARH  318.600000
# 24                      PUNJAB  364.600000
# 11              GUJARAT REGION  401.800000
# 8               EAST RAJASTHAN  408.500000
# 35          WEST UTTAR PRADESH  445.200000
# 9           EAST UTTAR PRADESH  493.500000
# 22    NORTH INTERIOR KARNATAKA  501.100000
# 25                  RAYALSEEMA  537.200000
# 20                  MATATHWADA  552.800000
# 33         WEST MADHYA PRADESH  619.807895
# 19          MADHYA MAHARASHTRA  644.300000
# 29                  TAMIL NADU  678.800000
# 30                   TELANGANA  742.600000

# %%
df_q1=df[df['Phase']=='Quarter1']
df_q2=df[df['Phase']=='Quarter2']
df_q3=df[df['Phase']=='Quarter3']
df_q4=df[df['Phase']=='Quarter4']
df_p5=df[df['Phase']=='Phase5']

# %%
df_q1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4021                LAKSHADWEEP  1921  37.6    0.0  16.8   82.4  156.3  326.2
# 4022                LAKSHADWEEP  1922  17.8   56.7   0.0  214.1  112.8  232.9
# 4023                LAKSHADWEEP  1923  43.7    1.6  25.0    0.0   13.5  372.8
# 4024                LAKSHADWEEP  1924  23.8    1.0   4.7   57.6  224.9  567.3
# 4025                LAKSHADWEEP  1925   2.3    7.5  15.5   32.6  244.2  327.5
#
# ...

# %%
df.drop(['1st Phase'],axis=1,inplace=True)

# %%
df_q1=df[df['Phase']=='Quarter1']
df_q2=df[df['Phase']=='Quarter2']
df_q3=df[df['Phase']=='Quarter3']
df_q4=df[df['Phase']=='Quarter4']
df_p5=df[df['Phase']=='Phase5']

# %%
##### 1st Quarter max,average,min rainfall in india
q1_max=df_q1.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='SUBDIVISION',ascending=True)
q1_mean=df_q1.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='SUBDIVISION',ascending=True)
q1_low=df_q1.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='SUBDIVISION',ascending=True)


   

##### 2nd Quarter max,average,min rainfall in india 
q2_max=df_q2.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='SUBDIVISION',ascending=True)
q2_mean=df_q2.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='SUBDIVISION',ascending=True)
q2_low=df_q2.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='SUBDIVISION',ascending=True)


##### 3rd Quarter max,average,min rainfall in india 
q3_max=df_q3.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='SUBDIVISION',ascending=True)
q3_mean=df_q3.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='SUBDIVISION',ascending=True)
q3_low=df_q3.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='SUBDIVISION',ascending=True)




##### 4th  Quarter max,average,min rainfall in india 
q4_max=df_q4.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='SUBDIVISION',ascending=True)
q4_mean=df_q4.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='SUBDIVISION',ascending=True)
q4_low=df_q4.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='SUBDIVISION',ascending=True)


#####  5th  Quarter max,average,min rainfall in india 

p5_max=df_p5.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].max().sort_values(by='SUBDIVISION',ascending=True)
p5_mean=df_p5.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].mean().sort_values(by='SUBDIVISION',ascending=True)
p5_low=df_p5.groupby(['SUBDIVISION'],as_index=False)['ANNUAL'].min().sort_values(by='SUBDIVISION',ascending=True)

# %%
p5_low
# Out:
#                            SUBDIVISION  ANNUAL
# 0            ANDAMAN & NICOBAR ISLANDS  2355.7
# 1                    ARUNACHAL PRADESH  1750.0
# 2                    ASSAM & MEGHALAYA  1743.5
# 3                                BIHAR   629.2
# 4                         CHHATTISGARH   956.7
# 5               COASTAL ANDHRA PRADESH   703.2
# 6                    COASTAL KARNATAKA  2793.2
# 7                  EAST MADHYA PRADESH   653.7
# 8                       EAST RAJASTHAN   285.3
# 9                   EAST UTTAR PRADESH   602.7
# 10                GANGETIC WEST BENGAL  1064.9
# 11                      GUJARAT REGION   623.0
# 12          HARYANA DELHI & CHANDIGARH   305.5
# 13                    HIMACHAL PRADESH   878.3
# 14                     JAMMU & KASHMIR   859.3
# 15                           JHARKHAND   697.1
# 16                              KERALA  2151.2
# 17                        KONKAN & GOA  2081.8
# 18                         LAKSHADWEEP  1033.5
# ...
